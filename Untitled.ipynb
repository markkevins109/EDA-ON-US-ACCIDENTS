# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\mark kevin\Downloads\US_Accidents_March23.csv\US_Accidents_March23.csv")
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# ...

# %%
numeric_columns = df.select_dtypes(include=['number']).columns
num_numeric_columns = len(numeric_columns)

print("Number of numeric columns:", num_numeric_columns)
# Out:
# Number of numeric columns: 13

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# End_Lat                  3402762
# End_Lng                  3402762
# Precipitation(in)        2203586
# Wind_Chill(F)            1999019
# Wind_Speed(mph)           571233
# Visibility(mi)            177098
# Wind_Direction            175206
# Humidity(%)               174144
# Weather_Condition         173459
# Temperature(F)            163853
# Pressure(in)              140679
# Weather_Timestamp         120228
# Nautical_Twilight          23246
# Civil_Twilight             23246
# Sunrise_Sunset             23246
# Astronomical_Twilight      23246
# Airport_Code               22635
# Street                     10869
# Timezone                    7808
# Zipcode                     1915
# City                         253
# Description                    5
# Traffic_Signal                 0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Country                        0
# ...

# %%
missing_percentages=df.isnull().sum().sort_values(ascending=False)/len(df)*100

# %%
missing_percentages
# Out:
# End_Lat                  44.029355
# End_Lng                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Nautical_Twilight         0.300787
# Civil_Twilight            0.300787
# Sunrise_Sunset            0.300787
# Astronomical_Twilight     0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# Traffic_Signal            0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# ...

# %%
missing_percentages=missing_percentages[missing_percentages>0]
missing_percentages
# Out:
# End_Lat                  44.029355
# End_Lng                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Nautical_Twilight         0.300787
# Civil_Twilight            0.300787
# Sunrise_Sunset            0.300787
# Astronomical_Twilight     0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# dtype: float64

# %%
missing_percentages.plot(kind="barh")
# Out:
# <Axes: >

# %%
columns_to_drop = missing_percentages[missing_percentages > 50]
df = df.drop(columns=columns_to_drop, inplace=True)

# %%
df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# ...

# %%
df.isnull().sum().sort_values(ascending=False)/len(df)*100
# Out:
# End_Lat                  44.029355
# End_Lng                  44.029355
# Precipitation(in)        28.512858
# Wind_Chill(F)            25.865904
# Wind_Speed(mph)           7.391355
# Visibility(mi)            2.291524
# Wind_Direction            2.267043
# Humidity(%)               2.253301
# Weather_Condition         2.244438
# Temperature(F)            2.120143
# Pressure(in)              1.820288
# Weather_Timestamp         1.555666
# Nautical_Twilight         0.300787
# Civil_Twilight            0.300787
# Sunrise_Sunset            0.300787
# Astronomical_Twilight     0.300787
# Airport_Code              0.292881
# Street                    0.140637
# Timezone                  0.101030
# Zipcode                   0.024779
# City                      0.003274
# Description               0.000065
# Traffic_Signal            0.000000
# Roundabout                0.000000
# Station                   0.000000
# Stop                      0.000000
# Traffic_Calming           0.000000
# ...

# %%
cities=df.City.unique()
len(cities)
# Out:
# 13679

# %%
cities_by_accident=df.City.value_counts()
cities_by_accident
# Out:
# Miami                           186917
# Houston                         169609
# Los Angeles                     156491
# Charlotte                       138652
# Dallas                          130939
#                                  ...
# Benkelman                            1
# Old Appleton                         1
# Wildrose                             1
# Mc Nabb                              1
# American Fork-Pleasant Grove         1
# Name: City, Length: 13678, dtype: int64

# %%
cities_by_accident[:20].plot(kind='bar')
# Out:
# <Axes: >

# %%
high_accident_cities=cities_by_accident[cities_by_accident>=1000]
low_accident_cities=cities_by_accident[cities_by_accident<1000]
print("high accidents count",len(high_accident_cities))
print("high accident percentage",len(high_accident_cities)/len(cities)*100)
len(low_accident_cities)/len(cities)*100
# Out:
# high accidents count 1218
# high accident percentage 8.904159660793917
# 91.0885298632941

# %%
import seaborn as sns
sns.histplot(high_accident_cities,log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
sns.histplot(low_accident_cities,log_scale=True)
# Out:
# <Axes: xlabel='City', ylabel='Count'>

# %%
low_accident_cities[low_accident_cities==1]
# Out:
# Lake Andes                      1
# Catoctin                        1
# Duck Hill                       1
# Westbrookville                  1
# Saint Croix                     1
#                                ..
# Benkelman                       1
# Old Appleton                    1
# Wildrose                        1
# Mc Nabb                         1
# American Fork-Pleasant Grove    1
# Name: City, Length: 1023, dtype: int64

# %%
high_s = list(high_accident_cities.keys())
state_list = df['State'].tolist()
state_unique_list = list(set(state_list))
state_unique_list_counts = [state_list.count(s) for s in state_unique_list]

import matplotlib.pyplot as plt
explode = [0.1 if state == high_s[0] else 0 for state in state_unique_list]

plt.figure(figsize=(10, 7))
plt.pie(state_unique_list_counts, labels=state_unique_list, autopct='%0.01f%%', explode=explode)
plt.title('Accidents Distribution by State')
plt.show()

# %%
df.Start_Time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 7728389    2019-08-23 18:03:25
# 7728390    2019-08-23 19:11:30
# 7728391    2019-08-23 19:00:21
# 7728392    2019-08-23 19:00:21
# 7728393    2019-08-23 18:52:06
# Name: Start_Time, Length: 7728394, dtype: object

# %%
import datetime as dt
#converting in datetime object
df.Start_Time=pd.to_datetime(df.Start_Time)
df.Start_Time[4]
# Out:
# Timestamp('2016-02-08 07:39:07')

# %%
df['Start_Time'].dt.hour.value_counts()
# Out:
# 7     587472
# 16    581969
# 8     577576
# 17    576015
# 15    525855
# 14    448846
# 18    432042
# 6     405837
# 13    396445
# 9     363034
# 11    355040
# 12    355001
# 10    342706
# 19    295121
# 5     228182
# 20    225226
# 21    191452
# 22    167645
# 4     159852
# 23    126539
# 0     112378
# 1      97071
# 2      93227
# 3      83863
# Name: Start_Time, dtype: int64

# %%
sns.distplot(df['Start_Time'].dt.hour,bins=24)
# Out:
# C:\Users\mark kevin\AppData\Local\Temp\ipykernel_6952\349827518.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Start_Time'].dt.hour,bins=24)
# <Axes: xlabel='Start_Time', ylabel='Density'>

# %%
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# C:\Users\mark kevin\AppData\Local\Temp\ipykernel_6952\4238415869.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# <Axes: xlabel='Start_Time'>

# %%
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 7728389   -117.379360
# 7728390   -117.148060
# 7728391   -117.847790
# 7728392   -118.403020
# 7728393   -117.230920
# Name: Start_Lng, Length: 7728394, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng,y=df.Start_Lat,size=0.001)#displays usa map
# Out:
# <Axes: xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# # FROM THE ABOVE ANALYSIS WE INFER THAT
# 1.Cities like Miami, Houston has reported most number of accidents.
# 2.From 13679 cities 1218 cities reported more than 1000 accident cases which is 8.90% of total cities.
# 3.OHIO State reported the most number of accidents of total accidents.
# 4.High percent of accidents occured in between 1PM to 5PM.
